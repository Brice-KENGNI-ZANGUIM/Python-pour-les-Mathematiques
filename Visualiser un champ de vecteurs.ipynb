# %% [markdown]
# <h2> <strong> Modules necessaires

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h1> <strong> Représentation 2D

# %% [markdown]
# <h2>  <strong> Représenter un vecteur à une position données $$ \vec{F}_{(0,1)} = (1,2) $$

# %%
position_x , position_y = 0,1
vecteur_x , vecteur_y = 1 , 2 
plt.quiver(position_x , position_y , vecteur_x , vecteur_y)
plt.show()

# %% [markdown]
# <h2>  <strong>  Représenter plusieurs vecteurs simultanément : $$ \vec{F}_{(x,0)} = (0,-1) $$

# %%
n = 61

# %%
position_x , position_y = np.linspace(-10,10,n), np.zeros(n)
vecteur_x , vecteur_y = 0 , -1

plt.quiver(position_x, position_y , vecteur_x ,  vecteur_y, width= n*.5e-4)

# %% [markdown]
# <h2> $$ \vec{F}_{(x,0)} = (0, \sin(x)\,\, ) $$

# %%
position_x , position_y = np.linspace(-10,10,n), np.zeros(n)
vecteur_x , vecteur_y = 0 , np.sin(position_x)

plt.quiver(position_x, position_y , vecteur_x ,  vecteur_y, width=  n*.5e-4)

# %%
position_x , position_y = np.linspace(-10,10,n), np.linspace(-10,10,n)
vecteur_x , vecteur_y = 0 , -1

plt.quiver(position_x, position_y , vecteur_x ,  vecteur_y, width=  n*.5e-4)

# %%
position_x , position_y = np.linspace(-10,10,n), np.sin(position_x)
vecteur_x , vecteur_y = 0 , -1

plt.quiver(position_x, position_y , vecteur_x ,  vecteur_y, width= n*.5e-4)

# %% [markdown]
# <h2>  <strong>  Champ de Vecteurs 2D : Meshgrid

# %%
n = 17

# %%
position_x , position_y = np.linspace(-10,10,n), np.linspace(-10,10,n)
mesh_position_x, mesh_position_y = np.meshgrid(position_x , position_y)
vecteur_x , vecteur_y = 0 , -1

plt.quiver(mesh_position_x, mesh_position_y , vecteur_x ,  vecteur_y, width= n*2.e-4)

# %%
position_x , position_y = np.linspace(-10,10,n), np.linspace(-10,10,n)
mesh_position_x, mesh_position_y = np.meshgrid(position_x , position_y)
vecteur_x , vecteur_y = 1 , -1

plt.quiver(mesh_position_x, mesh_position_y , vecteur_x ,  vecteur_y, width= n*2.e-4)

# %%
position_x , position_y = np.linspace( -10,10,2*n ), np.linspace( -10,10,2*n )
mesh_position_x, mesh_position_y = np.meshgrid( position_x , position_y )
vecteur_x , vecteur_y = np.sin( mesh_position_x ) , np.cos( mesh_position_y )

plt.quiver( mesh_position_x, mesh_position_y , vecteur_x ,  vecteur_y, width= n*1.5e-4 )

# %% [markdown]
# <h3> On souhaite visualiser dans $[0 , 2\pi]$ la fonction vectorielle : $$ \vec{F}(x,y) = x\cos(x)\,\hat{x} + y\sin(y)\,\hat{y}$$

# %%
n = 26

x_r, y_r = np.linspace( 0 , 2*np.pi , n ), np.linspace( 0, 2*np.pi , n )
x , y = np.meshgrid(  x_r , y_r )

f_x , f_y = x*np.sin(x) , y*np.cos(y)

plt.figure(figsize = ( 6.5, 6.5))
Q = plt.quiver(x , y , f_x , f_y , width = n*2e-4 , headlength = 8 , headwidth = 5 )
plt.quiverkey(Q , .84 , 1.025 , 1 , "=1 Kg.m/s", labelpos = "E")

plt.title("Impulsion flow")

plt.axis("scaled")
plt.xlim(-.5,6.8)
plt.ylim(-.5,6.8)
# Out:
# (-0.5, 6.8)

# %% [markdown]
# <h2>  <strong>  Lignes de champ

# %%
plt.streamplot(x , y , f_x , f_y, density = 3, linewidth= 0.6)

#plt.figure(figsize = ( 6.5, 6.5))
plt.title("Lignes de courant")

#plt.axis("scaled")
plt.show()

# %% [markdown]
# <h2>  <strong>  Imshow

# %%
n = 150
x_r, y_r = np.linspace( 0 , 2*np.pi , n ), np.linspace( 0, 2*np.pi , n )
x , y = np.meshgrid(  x_r , y_r )

f_x , f_y = x*np.sin(x) , y*np.cos(y)
f_mag = np.sqrt( f_x**2 + f_y**2 )

plt.figure(figsize = ( 6.5, 6.5))
plt.imshow( f_mag , origin ="lower" ,cmap ='gray')
plt.title("Impulsion flow             ")

plt.axis("scaled")
#plt.xlim(-.5,6.8)
#plt.ylim(-.5,6.8)
# Out:
# (-0.5, 149.5, -0.5, 149.5)

# %% [markdown]
# <h3> <strong> Formes d'un champ électrique $$ \vec {E}( \vec r) = \frac{kq}{r^2} \hat r = \frac{kq}{r^3}(x\hat x + y\hat y) $$  $$ |\vec {E(\vec r)}| = \frac{kq}{x^2 + y^2} $$

# %%
n = 16

x_r, y_r = np.linspace( -1 , 1 , n ), np.linspace( -1, 1 , n )
x , y = np.meshgrid(  x_r , y_r )
r = np.sqrt( x**2 + y**2 )

kq = 1

E_x , E_y = kq*x/r**3 , kq*y/r**3
E_mag = kq/r**2

plt.figure(figsize = ( 6.5, 6.5))
Q = plt.quiver(x , y , E_x , E_y , width = n*2e-4 , headlength = 11 , headwidth = 6 )
#plt.quiverkey(Q , .84 , 1.025 , 1 )#, "=1 Kg.m/s", labelpos = "E")

plt.title("Impulsion flow             ")
plt.axis("scaled")
#plt.xlim(-.5,6.8)
#plt.ylim(-.5,6.8)
# Out:
# (-1.1, 1.1, -1.1, 1.1)

# %% [markdown]
# <h2>  <strong>  Lignes de champ

# %%
plt.streamplot(x , y , E_x , E_y , density = 3, linewidth= 0.6)

#plt.figure(figsize = ( 6.5, 6.5))
plt.title("Lignes de champ électriques")

#plt.axis("scaled")
plt.show()

# %% [markdown]
# <h3> <strong> Exemple d'application : Soit le potentiel $$  V(x,y) = \sin(xy)  $$ Le champ électrique associé s'écrit : $$ \vec{E}(x,y) = - \vec {\nabla} V(x,y)  = - \frac{\partial V(x,y) }{\partial x} \hat x  - \frac{\partial V(x,y) }{\partial y} \hat y  = -( y  \hat x + x \hat y ) \cos (xy) $$

# %%
x_lb , x_ub = -np.pi , np.pi

def V ( n): 
    x = y = np.linspace(x_lb , x_ub , n)
    x , y = np.meshgrid(x , y)
    return x , y , np.sin(x*y)

def E ( n ) :
    x = y = np.linspace(x_lb , x_ub, n)
    x , y = np.meshgrid(x , y)
    return x , y , -y*np.cos(x*y) , -x*np.cos(x*y)

# %% [markdown]
# <h2>  <strong>  Lignes/surfaces équipotentielles

# %%
plt.figure( figsize = (9,6))

plt.contour(  *V(500) , 4)
plt.colorbar()
plt.axis("scaled")
plt.xlabel("x (m)")
plt.ylabel("y (m)")

plt.title("Lignes Equipotentielles")

plt.show()

# %%
plt.figure( figsize = (9,6))

plt.contour(  *V(500) , 200)
plt.colorbar()
plt.axis("scaled")
plt.xlabel("x (m)")
plt.ylabel("y (m)")

plt.title("Lignes Equipotentielles")

plt.show()

# %%
plt.figure( figsize = (9,6))

plt.imshow(  V(500)[-1].T )
plt.colorbar()
plt.axis("scaled")
plt.xlabel("x (m)")
plt.ylabel("y (m)")

plt.title("Lignes Equipotentielles")

plt.show()

# %% [markdown]
# <h2>  <strong>  Lignes de Champ électric

# %%
plt.figure(figsize = (9,6))

plt.quiver(*E(30))

plt.title("Lignes de champ Electrique")
plt.xlabel("x (m)")
plt.ylabel("y (m)")

plt.axis("scaled")
plt.show()

# %%
plt.figure(figsize = (9,6))

plt.streamplot( *E(12), density = 2, linewidth= 0.6)

plt.title("Lignes de champ Electrique")
plt.xlabel("x (m)")
plt.ylabel("y (m)")

plt.axis("scaled")
plt.show()

# %% [markdown]
# <h2>  <strong>  Équipotentielles et Lignes de Champ électrique

# %%
plt.figure( figsize = (10,8))

plt.contour(  *V(300) , 6 )
plt.colorbar()

plt.quiver(*E(15), pivot = "middle")

plt.axis("scaled")
plt.xlabel("x (m)")
plt.ylabel("y (m)")

plt.title("Equipotentielles + Lignes de champ")

plt.show()

# %%
plt.figure( figsize = (10,8))

v = V(300)

plt.imshow(  v[-1], extent=( v[0].min(), v[0].max(), v[0].min(), v[0].max() )  )
plt.colorbar()

plt.quiver(*E(15), pivot = "middle", color = "red")

plt.axis("scaled")
plt.xlabel("x (m)")
plt.ylabel("y (m)")

plt.title("Equipotentielles + Lignes de champ")

plt.show()

# %% [markdown]
# <h1> <strong> Cas d'un champ radial

# %%
x_lb , x_ub = -np.pi , np.pi

def V ( n): 
    x = y = np.linspace(x_lb , x_ub , n)
    x , y = np.meshgrid(x , y)
    return x , y , np.sin(x*2y)

def E ( n ) :
    x = y = np.linspace(x_lb , x_ub, n)
    x , y = np.meshgrid(x , y)
    return x , y , -y*np.cos(x*y) , -x*np.cos(x*y)

# %% [markdown]
# <h1> <strong> Représentation 3D

# %% [markdown]
# <h2>  <strong>  Un seul vecteur

# %%
vecteur_1 = [1,0,0]
vecteur_2 = [0,1,0]
vecteur_3 = [0,0,1]

vecteur_origine = [0,0,0]

# %%
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')

ax.quiver(*vecteur_origine, *vecteur_1, color= "b")

ax.set_xlim(-1,2)
ax.set_ylim(-1,2)
ax.set_zlim(0,2)

ax.set_xlabel("axe X")
ax.set_ylabel("axe Y")
ax.set_zlabel("axe Z")
# Out:
# Text(0.5, 0, 'axe Z')

# %% [markdown]
# <h2>  <strong>  Vecteurs de base

# %%
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')

ax.quiver(*vecteur_origine, *vecteur_1, color= "b")
ax.quiver(*vecteur_origine, *vecteur_2, color="g")
ax.quiver(*vecteur_origine, *vecteur_3, color= "r")


ax.set_xlim(-1,2)
ax.set_ylim(-1,2)
ax.set_zlim(0,2)

ax.set_xlabel("axe X")
ax.set_ylabel("axe Y")
ax.set_zlabel("axe Z")
# Out:
# Text(0.5, 0, 'axe Z')

# %% [markdown]
# <h2>  <strong>  Changement de l'axe de vue

# %%
fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')

ax.quiver(*vecteur_origine, *vecteur_1, color= "b")
ax.quiver(*vecteur_origine, *vecteur_2, color="g")
ax.quiver(*vecteur_origine, *vecteur_3, color= "r")

ax.set_xlim(-1,2)
ax.set_ylim(-1,2)
ax.set_zlim(-1,2)

ax.set_xlabel("axe X")
ax.set_ylabel("axe Y")
ax.set_zlabel("axe Z")

ax.view_init( 30 , 15 )

# %% [markdown]
# <h2>  <strong>  Changement de l'axe de vue

# %%
n = 7

position_x, position_y, position_z = np.linspace(-10,10,n), np.linspace(-10,10,n), np.linspace(-10,10,n)
position_x, position_y, position_z = np.meshgrid(position_x, position_y, position_z)
vecteur_x, vecteur_y, vecteur_z = position_x, position_y, position_z

fig = plt.figure(figsize = (8,6))
ax = plt.axes(projection = '3d')

ax.quiver( position_x , position_y , position_z , vecteur_x, vecteur_y, vecteur_z , length=0.07, arrow_length_ratio=0.3)

ax.set_xlim(-12,12)
ax.set_ylim(-12,12)
ax.set_zlim(-12,12)

ax.set_xlabel("axe X")
ax.set_ylabel("axe Y")
ax.set_zlabel("axe Z")

ax.view_init( 20 , 25 )
